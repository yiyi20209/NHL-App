# %%
import json
import pandas as pd
import os

#Tidy data for one single game, hepler function of tidy_data
def tidy_one_game_data(raw_data: dict):
    '''
    To extract the features wanted from one game into a pandas dataframe, helper function of tidyData
    returns: pd.DataFrame, or None if liveData doesn't exist
    '''
    
    
    if 'liveData' not in raw_data:
        return None
    
    df = pd.DataFrame(columns=['gameID_eventID', 'period', 'dateTime', 'gameID', 'team', 'goal', 'x', 'y', 'shooter', 'goalie', 'shotType', 'emptyNet', 'strength', 'gameType','home','away', 'season'])
    types = ['Shot', 'Goal']
    gameID = raw_data['gamePk']
    gameType = raw_data['gameData']['game']['type']
    home = raw_data['gameData']['teams']['home']['name']
    away = raw_data['gameData']['teams']['away']['name']
    season = raw_data['gameData']['game']['season']
    i = 0
    
    #For each play, if event is type of 'Shot' or 'Goal', acquire the features needed
    for play in raw_data['liveData']['plays']['allPlays']:
        if play['result']['event'] in types:
            about = play['about']
            gameID_eventID = str(gameID)+'_'+str(about['eventId'])
            period = about['period']
            dateTime = about['dateTime']
            team = play['team']['name']
            goal = False
            shooter = ''
            goalie = ''
            emptyNet = ''
            strength = ''
            
            if play['result']['event'] == 'Goal':
                goal = True
                emptyNet = play['result'].get('emptyNet', None)
                strength = play['result'].get('strength',None).get('name', None)
                for player in play['players']:
                    if player['playerType'] == 'Scorer':
                        shooter = player['player']['fullName']
                    if player['playerType'] == 'Goalie':
                        goalie =  player['player']['fullName']
            else:
                for player in play['players']:
                    if player['playerType'] == 'Shooter':
                        shooter = player['player']['fullName']
                    if player['playerType'] == 'Goalie':
                        goalie =  player['player']['fullName']
            x = play['coordinates'].get('x', None)
            y = play['coordinates'].get('y',None)
            shotType = play['result'].get('secondaryType',None)
            
            df.loc[i] = [gameID_eventID, period, dateTime, gameID, team, goal, x, y, shooter, goalie, shotType, emptyNet, strength, gameType,home,away, season]
            i += 1
            
    return df

# %%
def tidy_data(dir_path: str) -> pd.DataFrame:
    '''
    To extract the features wanted from all games stored in the JSON files of directory dir_path (nested or not) into a pandas dataframe
    returns: pd.DataFrame
    '''
    
    
    df = pd.DataFrame()
    init = True
    
    for dir, subdirs, files in os.walk(dir_path):
           for name in files:
                file_path = os.path.join(dir, name)
                with open(file_path, 'r') as file:
                    data = file.read()
                raw_data = json.loads(data)
                if init:
                    df = tidy_one_game_data(raw_data)
                    if df is not None:
                        init = False
                else:
                    new_df = tidy_one_game_data(raw_data)
                    if new_df is not None:
                        df = pd.concat([df, new_df],ignore_index=True)
    #write the dataframe to CSV so we don't have to re-run this code everytime
    df.to_csv('data/tidy.csv', index=False)                     
    return df

df_tidy = tidy_data('data')

# %%
df_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387829 entries, 0 to 387828
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   gameID_eventID  387829 non-null  object
#  1   period          387829 non-null  object
#  2   dateTime        387829 non-null  object
#  3   gameID          387829 non-null  object
#  4   team            387829 non-null  object
#  5   goal            387829 non-null  object
#  6   x               387813 non-null  object
#  7   y               387814 non-null  object
#  8   shooter         387829 non-null  object
#  9   goalie          387829 non-null  object
#  10  shotType        387780 non-null  object
#  11  emptyNet        386826 non-null  object
#  12  strength        387829 non-null  object
#  13  gameType        387829 non-null  object
#  14  home            387829 non-null  object
#  15  away            387829 non-null  object
#  16  season          387829 non-null  object
# dtypes: object(17)
# memory usage: 50.3+ MB

# %%
df_tidy
# Out:
#         gameID_eventID period              dateTime      gameID  \
# 0        2016030111_53      1  2017-04-12T23:11:54Z  2016030111
# 1        2016030111_55      1  2017-04-12T23:13:24Z  2016030111
# 2        2016030111_56      1  2017-04-12T23:13:32Z  2016030111
# 3        2016030111_57      1  2017-04-12T23:15:08Z  2016030111
# 4        2016030111_62      1  2017-04-12T23:18:02Z  2016030111
# ...                ...    ...                   ...         ...
# 387824  2020020868_490      3  2021-05-09T05:02:46Z  2020020868
# 387825  2020020868_498      4  2021-05-09T05:05:28Z  2020020868
# 387826  2020020868_500      4  2021-05-09T05:06:21Z  2020020868
# 387827  2020020868_751      4  2021-05-09T05:07:10Z  2020020868
# 387828  2020020868_753      4  2021-05-09T05:05:28Z  2020020868
#
#                       team   goal     x     y         shooter  \
# 0       Montréal Canadiens  False  -8.0 -36.0     Dwight King
# 1         New York Rangers  False  85.0  -6.0       Rick Nash
# 2       Montréal Canadiens  False -69.0 -35.0  Max Pacioretty
# 3       Montréal Canadiens  False -55.0 -17.0     Dwight King
# 4       Montréal Canadiens  False -58.0 -28.0      Paul Byron
# ...                    ...    ...   ...   ...             ...
# 387824     San Jose Sharks  False  71.0 -16.0     Noah Gregor
# 387825     San Jose Sharks  False -68.0 -14.0   Erik Karlsson
# 387826     Arizona Coyotes  False  56.0  11.0   Conor Garland
# 387827     Arizona Coyotes  False  73.0   6.0   Conor Garland
# 387828     Arizona Coyotes   True  76.0 -15.0     Phil Kessel
#
#                   goalie    shotType emptyNet strength gameType  \
# 0       Henrik Lundqvist  Wrist Shot                          P
# 1            Carey Price  Wrist Shot                          P
# 2       Henrik Lundqvist  Wrist Shot                          P
# 3       Henrik Lundqvist   Slap Shot                          P
# 4       Henrik Lundqvist  Wrist Shot                          P
# ...                  ...         ...      ...      ...      ...
# 387824         Adin Hill    Backhand                          R
# 387825         Adin Hill  Wrist Shot                          R
# 387826  Alexei Melnichuk  Wrist Shot                          R
# 387827  Alexei Melnichuk  Wrist Shot                          R
# 387828  Alexei Melnichuk  Wrist Shot    False     Even        R
#
#                       home              away    season
# 0       Montréal Canadiens  New York Rangers  20162017
# 1       Montréal Canadiens  New York Rangers  20162017
# 2       Montréal Canadiens  New York Rangers  20162017
# 3       Montréal Canadiens  New York Rangers  20162017
# 4       Montréal Canadiens  New York Rangers  20162017
# ...                    ...               ...       ...
# 387824     San Jose Sharks   Arizona Coyotes  20202021
# 387825     San Jose Sharks   Arizona Coyotes  20202021
# 387826     San Jose Sharks   Arizona Coyotes  20202021
# 387827     San Jose Sharks   Arizona Coyotes  20202021
# 387828     San Jose Sharks   Arizona Coyotes  20202021
#
# [387829 rows x 17 columns]

# %%
df_tidy.head(10)
# Out:
#   gameID_eventID period              dateTime      gameID                team  \
# 0  2016030111_53      1  2017-04-12T23:11:54Z  2016030111  Montréal Canadiens
# 1  2016030111_55      1  2017-04-12T23:13:24Z  2016030111    New York Rangers
# 2  2016030111_56      1  2017-04-12T23:13:32Z  2016030111  Montréal Canadiens
# 3  2016030111_57      1  2017-04-12T23:15:08Z  2016030111  Montréal Canadiens
# 4  2016030111_62      1  2017-04-12T23:18:02Z  2016030111  Montréal Canadiens
# 5  2016030111_64      1  2017-04-12T23:18:39Z  2016030111  Montréal Canadiens
# 6  2016030111_67      1  2017-04-12T23:20:15Z  2016030111  Montréal Canadiens
# 7  2016030111_68      1  2017-04-12T23:20:25Z  2016030111    New York Rangers
# 8  2016030111_71      1  2017-04-12T23:21:50Z  2016030111  Montréal Canadiens
# 9  2016030111_72      1  2017-04-12T23:22:01Z  2016030111  Montréal Canadiens
#
#     goal     x     y            shooter            goalie    shotType  \
# 0  False  -8.0 -36.0        Dwight King  Henrik Lundqvist  Wrist Shot
# 1  False  85.0  -6.0          Rick Nash       Carey Price  Wrist Shot
# 2  False -69.0 -35.0     Max Pacioretty  Henrik Lundqvist  Wrist Shot
# 3  False -55.0 -17.0        Dwight King  Henrik Lundqvist   Slap Shot
# 4  False -58.0 -28.0         Paul Byron  Henrik Lundqvist  Wrist Shot
# 5  False -45.0 -33.0      Andrei Markov  Henrik Lundqvist  Wrist Shot
# 6  False  54.0 -27.0        Jordie Benn  Henrik Lundqvist  Wrist Shot
# 7  False  49.0   1.0       Derek Stepan       Carey Price  Wrist Shot
# 8  False -35.0  11.0    Nikita Nesterov  Henrik Lundqvist  Wrist Shot
# 9  False -54.0 -33.0  Alexander Radulov  Henrik Lundqvist   Slap Shot
#
#   emptyNet strength gameType                home              away    season
# 0                          P  Montréal Canadiens  New York Rangers  20162017
# 1                          P  Montréal Canadiens  New York Rangers  20162017
# 2                          P  Montréal Canadiens  New York Rangers  20162017
# 3                          P  Montréal Canadiens  New York Rangers  20162017
# 4                          P  Montréal Canadiens  New York Rangers  20162017
# 5                          P  Montréal Canadiens  New York Rangers  20162017
# 6                          P  Montréal Canadiens  New York Rangers  20162017
# 7                          P  Montréal Canadiens  New York Rangers  20162017
# 8                          P  Montréal Canadiens  New York Rangers  20162017
# 9                          P  Montréal Canadiens  New York Rangers  20162017
