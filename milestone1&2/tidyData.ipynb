# %%
# import comet_ml at the top of your file
from comet_ml import Experiment

# Create an experiment with your api key
with open('COMET_API_KEY.txt', 'r') as f:
    key = f.read()
    
experiment = Experiment(
    api_key=key,
    project_name="nhl-analytics",
    workspace="ift6758-22-team2",
)


import json
import pandas as pd
import os

from tidyData import *
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ift6758-22-team2/nhl-analytics/acf3478af3d1474eb6fdbab970370d9c

# %%
df_tidy = tidy_data('data/2017/R/2017021065.json')
# Out:
# C:\Users\Yi Cong\IFT6758_Project_Milestone-1\Milestone2\tidyData.py:76: RuntimeWarning: divide by zero encountered in double_scalars
#   angle = np.arctan(np.abs(y) / abs(x-89))

# %%
pd.set_option('display.max_columns', None)
df_tidy
# Out:
#     index  gameID_eventID game_period              dateTime      gameID  \
# 0       0   2017021065_13           1  2018-03-12T23:11:06Z  2017021065
# 1       1   2017021065_14           1  2018-03-12T23:11:11Z  2017021065
# 2       2   2017021065_16           1  2018-03-12T23:11:55Z  2017021065
# 3       3   2017021065_17           1  2018-03-12T23:12:22Z  2017021065
# 4       4   2017021065_18           1  2018-03-12T23:12:30Z  2017021065
# ..    ...             ...         ...                   ...         ...
# 66     66  2017021065_775           4  2018-03-13T01:46:55Z  2017021065
# 67     67  2017021065_776           4  2018-03-13T01:47:06Z  2017021065
# 68     68  2017021065_777           4  2018-03-13T01:47:34Z  2017021065
# 69     69  2017021065_780           4  2018-03-13T01:49:14Z  2017021065
# 70     70  2017021065_782           4  2018-03-13T01:50:50Z  2017021065
#
#                    team  goal     x     y            shooter  \
# ...

# %%
experiment.log_dataframe_profile(
    df_tidy, 
    name='wpg_v_wsh_2017021065',  # keep this name
    dataframe_format='csv'  # ensure you set this flag!
)
experiment.end()
# Out:
# COMET WARNING: pandas_profiling is required to log profile; ignoring
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/ift6758-22-team2/nhl-analytics/acf3478af3d1474eb6fdbab970370d9c
# COMET INFO:   Uploads:
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     dataframe                    : 1 (22.18 KB)
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     git-patch (uncompressed)     : 1 (39.21 KB)
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     source_code                  : 1
# ...

# %%
df_tidy[df_tidy['time_since_powerplay_started'] != 0]
# Out:
#     index  gameID_eventID game_period              dateTime      gameID  \
# 5       5   2017021065_21           1  2018-03-12T23:13:58Z  2017021065
# 6       6   2017021065_23           1  2018-03-12T23:15:15Z  2017021065
# 7       7   2017021065_25           1  2018-03-12T23:15:33Z  2017021065
# 8       8   2017021065_29           1  2018-03-12T23:16:38Z  2017021065
# 9       9   2017021065_30           1  2018-03-12T23:17:54Z  2017021065
# 17     17  2017021065_210           1  2018-03-12T23:42:51Z  2017021065
# 18     18  2017021065_215           1  2018-03-12T23:45:50Z  2017021065
# 19     19  2017021065_216           1  2018-03-12T23:46:29Z  2017021065
# 39     39  2017021065_435           2  2018-03-13T00:35:42Z  2017021065
# 64     64  2017021065_773           4  2018-03-13T01:46:43Z  2017021065
# 65     65  2017021065_774           4  2018-03-13T01:46:47Z  2017021065
# 66     66  2017021065_775           4  2018-03-13T01:46:55Z  2017021065
# ...

# %%
print(df_tidy['nbFriendly_non_goalie_skaters'].max())
print(df_tidy['nbOpposing_non_goalie_skaters'].max())
print(df_tidy['nbFriendly_non_goalie_skaters'].min())
print(df_tidy['nbOpposing_non_goalie_skaters'].min())
df_tidy[df_tidy.nbOpposing_non_goalie_skaters == 3]
# Out:
# 5
# 5
# 4
# 3
#    index gameID_eventID game_period              dateTime      gameID  \
# 6      6  2017021065_23           1  2018-03-12T23:15:15Z  2017021065
# 7      7  2017021065_25           1  2018-03-12T23:15:33Z  2017021065
# 8      8  2017021065_29           1  2018-03-12T23:16:38Z  2017021065
# 9      9  2017021065_30           1  2018-03-12T23:17:54Z  2017021065
#
#                   team  goal     x     y            shooter  \
# 6  Washington Capitals     0 -59.0  19.0       John Carlson
# 7  Washington Capitals     0 -84.0 -10.0         T.J. Oshie
# 8  Washington Capitals     1 -57.0 -20.0      Alex Ovechkin
# 9  Washington Capitals     0 -80.0   7.0  Nicklas Backstrom
#
#               goalie    shotType  emptyNet    strength gameType  \
# 6  Connor Hellebuyck   Slap Shot         0                    R
# 7  Connor Hellebuyck  Wrist Shot         0                    R
# 8  Connor Hellebuyck  Wrist Shot         0  Power Play        R
# ...

# %%
df = tidy_data('data')
# Out:
# C:\Users\Yi Cong\IFT6758_Project_Milestone-1\Milestone2\tidyData.py:74: RuntimeWarning: divide by zero encountered in double_scalars
#   angle=np.arctan(np.abs(y) / abs(x+89))
# C:\Users\Yi Cong\IFT6758_Project_Milestone-1\Milestone2\tidyData.py:76: RuntimeWarning: divide by zero encountered in double_scalars
#   angle = np.arctan(np.abs(y) / abs(x-89))

# %%
df.to_csv('data/tidy_data.csv')
